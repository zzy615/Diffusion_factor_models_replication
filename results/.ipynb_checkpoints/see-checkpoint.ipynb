# %%
import numpy as np
import os

# %%
np.load('eigenvalues_error_512.npy',allow_pickle=True)
# Out:
# array({'synthetic_error': np.float64(0.325), 'real_error': np.float64(0.018), 'ratio': np.float64(18.056)},
#       dtype=object)
